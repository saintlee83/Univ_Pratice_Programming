# %%
from PIL import Image

pil_image = Image.open("test.png")

print(pil_image.format)

print(pil_image.size)
print(pil_image.mode)
print(pil_image.width)
print(pil_image.height)

pil_image.show()
# Out:
# PNG
# (1920, 1440)
# RGBA
# 1920
# 1440

# %%
from skimage import data
from PIL import Image

# %%
img_array = data.chelsea()
img_array.shape
# Out:
# (300, 451, 3)

# %%
img = Image.fromarray(img_array)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
img.show()

# %%
fstr = 'output_pil.jpg'

img.save(
  fstr,
  format='JPEG',
  quality=80,
)

# %%
n_img = Image.open('output_pil.jpg')

# %%
import matplotlib.pyplot as plt

plt.imshow(n_img)
plt.show()
